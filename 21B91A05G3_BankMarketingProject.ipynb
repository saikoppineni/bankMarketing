# %%
#step 1 :
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandasql as psql

# Set to display all the columns of the dataset
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",500)
pd.options.display.float_format = '{:.4f}'.format

#Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#step 2 :
#Load the data
bank = pd.read_csv(r'C:\Users\saiko\Downloads\bank-additional-full-conv.csv')
bank
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon       261         1    999         0
# 1      telephone   may         mon       149         1    999         0
# 2      telephone   may         mon       226         1    999         0
# 3      telephone   may         mon       151         1    999         0
# 4      telephone   may         mon       307         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41183   cellular   nov         fri       334         1    999         0
# 41184   cellular   nov         fri       383         1    999         0
# 41185   cellular   nov         fri       189         2    999         0
# 41186   cellular   nov         fri       442         1    999         0
# 41187   cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 1      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 2      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 3      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 4      nonexistent        1.1000         93.9940       -36.4000     4.8570
# ...            ...           ...             ...            ...        ...
# 41183  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41184  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41185  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41186  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41187      failure       -1.1000         94.7670       -50.8000     1.0280
#
#        nr.employed    y
# 0        5191.0000   no
# 1        5191.0000   no
# 2        5191.0000   no
# 3        5191.0000   no
# 4        5191.0000   no
# ...            ...  ...
# 41183    4963.6000  yes
# 41184    4963.6000   no
# 41185    4963.6000   no
# 41186    4963.6000  yes
# 41187    4963.6000   no
#
# [41188 rows x 21 columns]

# %%
#Step -3
#Copy to back_up file
bank_copy = bank.copy()
#Display first 5 records
bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0        1.1000         93.9940       -36.4000     4.8570    5191.0000  no
# 1        1.1000         93.9940       -36.4000     4.8570    5191.0000  no
# 2        1.1000         93.9940       -36.4000     4.8570    5191.0000  no
# 3        1.1000         93.9940       -36.4000     4.8570    5191.0000  no
# 4        1.1000         93.9940       -36.4000     4.8570    5191.0000  no

# %%
#Step -4
#Display the data set information
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
# display the random sample of dataset 

bank.sample(5)
# Out:
#        age          job  marital            education  default housing loan  \
# 25486   39  blue-collar  married             basic.9y       no     yes   no
# 26780   39       admin.   single          high.school       no     yes  yes
# 40554   72      retired  married  professional.course       no      no   no
# 3153    46    housemaid  married             basic.4y       no     yes   no
# 608     37  blue-collar  married             basic.9y  unknown      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 25486   cellular   nov         wed       158         1    999         0
# 26780   cellular   nov         thu        44         2    999         1
# 40554   cellular   sep         wed         1         1    999         1
# 3153   telephone   may         thu       158         1    999         0
# 608    telephone   may         tue       258         5    999         0
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 25486  nonexistent       -0.1000         93.2000       -42.0000     4.1200
# 26780      failure       -0.1000         93.2000       -42.0000     4.0760
# 40554      failure       -1.1000         94.1990       -37.5000     0.8860
# 3153   nonexistent        1.1000         93.9940       -36.4000     4.8600
# 608    nonexistent        1.1000         93.9940       -36.4000     4.8570
#
#        nr.employed   y
# 25486    5195.8000  no
# 26780    5195.8000  no
# 40554    4963.6000  no
# 3153     5191.0000  no
# 608      5191.0000  no

# %%
#Step -5
# Checking for any duplicate values
bank_dup = bank[bank.duplicated(keep='last')]
bank_dup
# Out:
#        age          job   marital            education  default housing loan  \
# 1265    39  blue-collar   married             basic.6y       no      no   no
# 12260   36      retired   married              unknown       no      no   no
# 14155   27   technician    single  professional.course       no      no   no
# 16819   47   technician  divorced          high.school       no     yes   no
# 18464   32   technician    single  professional.course       no     yes   no
# 20072   55     services   married          high.school  unknown      no   no
# 20531   41   technician   married  professional.course       no     yes   no
# 25183   39       admin.   married    university.degree       no      no   no
# 28476   24     services    single          high.school       no     yes   no
# 32505   35       admin.   married    university.degree       no     yes   no
# 36950   45       admin.   married    university.degree       no      no   no
# 38255   71      retired    single    university.degree       no      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 1265   telephone   may         thu       124         1    999         0
# 12260  telephone   jul         thu        88         1    999         0
# 14155   cellular   jul         mon       331         2    999         0
# 16819   cellular   jul         thu        43         3    999         0
# 18464   cellular   jul         thu       128         1    999         0
# 20072   cellular   aug         mon        33         1    999         0
# 20531   cellular   aug         tue       127         1    999         0
# 25183   cellular   nov         tue       123         2    999         0
# 28476   cellular   apr         tue       114         1    999         0
# 32505   cellular   may         fri       348         4    999         0
# 36950   cellular   jul         thu       252         1    999         0
# 38255  telephone   oct         tue       120         1    999         0
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 1265   nonexistent        1.1000         93.9940       -36.4000     4.8550
# 12260  nonexistent        1.4000         93.9180       -42.7000     4.9660
# 14155  nonexistent        1.4000         93.9180       -42.7000     4.9620
# 16819  nonexistent        1.4000         93.9180       -42.7000     4.9620
# 18464  nonexistent        1.4000         93.9180       -42.7000     4.9680
# 20072  nonexistent        1.4000         93.4440       -36.1000     4.9650
# 20531  nonexistent        1.4000         93.4440       -36.1000     4.9660
# 25183  nonexistent       -0.1000         93.2000       -42.0000     4.1530
# 28476  nonexistent       -1.8000         93.0750       -47.1000     1.4230
# 32505  nonexistent       -1.8000         92.8930       -46.2000     1.3130
# 36950  nonexistent       -2.9000         92.4690       -33.6000     1.0720
# 38255  nonexistent       -3.4000         92.4310       -26.9000     0.7420
#
#        nr.employed    y
# 1265     5191.0000   no
# 12260    5228.1000   no
# 14155    5228.1000   no
# 16819    5228.1000   no
# 18464    5228.1000   no
# 20072    5228.1000   no
# 20531    5228.1000   no
# 25183    5195.8000   no
# 28476    5099.1000   no
# 32505    5099.1000   no
# 36950    5076.2000  yes
# 38255    5017.5000   no

# %%
#dropping duplicates from the dataset
bank.drop_duplicates()
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon       261         1    999         0
# 1      telephone   may         mon       149         1    999         0
# 2      telephone   may         mon       226         1    999         0
# 3      telephone   may         mon       151         1    999         0
# 4      telephone   may         mon       307         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41183   cellular   nov         fri       334         1    999         0
# 41184   cellular   nov         fri       383         1    999         0
# 41185   cellular   nov         fri       189         2    999         0
# 41186   cellular   nov         fri       442         1    999         0
# 41187   cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 1      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 2      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 3      nonexistent        1.1000         93.9940       -36.4000     4.8570
# 4      nonexistent        1.1000         93.9940       -36.4000     4.8570
# ...            ...           ...             ...            ...        ...
# 41183  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41184  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41185  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41186  nonexistent       -1.1000         94.7670       -50.8000     1.0280
# 41187      failure       -1.1000         94.7670       -50.8000     1.0280
#
#        nr.employed    y
# 0        5191.0000   no
# 1        5191.0000   no
# 2        5191.0000   no
# 3        5191.0000   no
# 4        5191.0000   no
# ...            ...  ...
# 41183    4963.6000  yes
# 41184    4963.6000   no
# 41185    4963.6000   no
# 41186    4963.6000  yes
# 41187    4963.6000   no
#
# [41176 rows x 21 columns]

# %%
#Step 6
# Checking if there are any null values
bank.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#Step -7
#Display the unique values of the data set
bank.nunique()
# Out:
# age                 78
# job                 12
# marital              4
# education            8
# default              3
# housing              3
# loan                 3
# contact              2
# month               10
# day_of_week          5
# duration          1544
# campaign            42
# pdays               27
# previous             8
# poutcome             3
# emp.var.rate        10
# cons.price.idx      26
# cons.conf.idx       26
# euribor3m          316
# nr.employed         11
# y                    2
# dtype: int64

# %% [markdown]
# # 'y' is the Target Variable

# %%
bank.y.value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
# Count the target or dependent variable by 'yes' & 'no' and their proportion 
# (>= 10 : 1, then the dataset is imbalance data)

bank_count = bank.y.value_counts()
print("proportion: ",bank_count[0]/bank_count[1],":1")
# Out:
# proportion:  7.876724137931035 :1

# %%
#Display the unique values by count for 'job'
bank['job'].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
#Display the unique values by count for 'marital'
bank['marital'].value_counts()
# Out:
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64

# %%
#Display the unique values by count for 'education'
bank['education'].value_counts()
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %%
#Display the unique values by count for 'default'
bank['default'].value_counts()
# Out:
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %%
#Display the unique values by count for 'housing'
bank['housing'].value_counts()
# Out:
# yes        21576
# no         18622
# unknown      990
# Name: housing, dtype: int64

# %%
#Display the unique values by count for 'loan'
bank['loan'].value_counts()
# Out:
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64

# %%
#Display the unique values by count for 'contact'
bank['contact'].value_counts()
# Out:
# cellular     26144
# telephone    15044
# Name: contact, dtype: int64

# %%
#Display the unique values by count for 'month'
bank['month'].value_counts()
# Out:
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: month, dtype: int64

# %%
#Display the unique values by count for 'day_of_week'
bank['day_of_week'].value_counts()
# Out:
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: day_of_week, dtype: int64

# %%
#Display the unique values by count for 'poutcome'
bank['poutcome'].value_counts()
# Out:
# nonexistent    35563
# failure         4252
# success         1373
# Name: poutcome, dtype: int64

# %%
#Display the unique values by count for 'y'
bank['y'].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
#Step -8,9
#use LabelEncoder for target variable
object_col = ["job", "marital", "education","default","housing","loan",'contact','month','day_of_week','poutcome','y']
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for col in object_col:
    bank[col] = LE.fit_transform(bank[col])

# %%
bank['job'].value_counts()
# Out:
# 0     10422
# 1      9254
# 9      6743
# 7      3969
# 4      2924
# 5      1720
# 2      1456
# 6      1421
# 3      1060
# 10     1014
# 8       875
# 11      330
# Name: job, dtype: int64

# %%
bank['marital'].value_counts()
# Out:
# 1    24928
# 2    11568
# 0     4612
# 3       80
# Name: marital, dtype: int64

# %%
bank['education'].value_counts()
# Out:
# 6    12168
# 3     9515
# 2     6045
# 5     5243
# 0     4176
# 1     2292
# 7     1731
# 4       18
# Name: education, dtype: int64

# %%
bank['default'].value_counts()
# Out:
# 0    32588
# 1     8597
# 2        3
# Name: default, dtype: int64

# %%
bank['housing'].value_counts()
# Out:
# 2    21576
# 0    18622
# 1      990
# Name: housing, dtype: int64

# %%
bank['loan'].value_counts()
# Out:
# 0    33950
# 2     6248
# 1      990
# Name: loan, dtype: int64

# %%
bank['contact'].value_counts()
# Out:
# 0    26144
# 1    15044
# Name: contact, dtype: int64

# %%
bank['month'].value_counts()
# Out:
# 6    13769
# 3     7174
# 1     6178
# 4     5318
# 7     4101
# 0     2632
# 8      718
# 9      570
# 5      546
# 2      182
# Name: month, dtype: int64

# %%
bank['day_of_week'].value_counts()
# Out:
# 2    8623
# 1    8514
# 4    8134
# 3    8090
# 0    7827
# Name: day_of_week, dtype: int64

# %%
bank['poutcome'].value_counts()
# Out:
# 1    35563
# 0     4252
# 2     1373
# Name: poutcome, dtype: int64

# %%
#Display the unique values by count for 'gender'
bank['y'].value_counts()
# Out:
# 0    36548
# 1     4640
# Name: y, dtype: int64

# %%
#Display the data set information
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  int32
#  2   marital         41188 non-null  int32
#  3   education       41188 non-null  int32
#  4   default         41188 non-null  int32
#  5   housing         41188 non-null  int32
#  6   loan            41188 non-null  int32
#  7   contact         41188 non-null  int32
#  8   month           41188 non-null  int32
#  9   day_of_week     41188 non-null  int32
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  int32
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  int32
# dtypes: float64(5), int32(11), int64(5)
# memory usage: 4.9 MB

# %%
cols=['age','job','marital','education','default','housing','loan','month','day_of_week','duration','campaign','pdays','previous','emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']
bs=bank[cols]
bs.corr()
# Out:
#                    age     job  marital  education  default  housing    loan  \
# age             1.0000  0.0012  -0.3898    -0.1179   0.1650  -0.0016 -0.0074
# job             0.0012  1.0000   0.0279     0.1341  -0.0283   0.0070 -0.0102
# marital        -0.3898  0.0279   1.0000     0.1092  -0.0795   0.0105  0.0058
# education      -0.1179  0.1341   0.1092     1.0000  -0.1869   0.0168  0.0064
# default         0.1650 -0.0283  -0.0795    -0.1869   1.0000  -0.0158 -0.0038
# housing        -0.0016  0.0070   0.0105     0.0168  -0.0158   1.0000  0.0443
# loan           -0.0074 -0.0102   0.0058     0.0064  -0.0038   0.0443  1.0000
# month          -0.0249 -0.0332  -0.0076    -0.0827  -0.0158  -0.0181 -0.0057
# day_of_week    -0.0176 -0.0008   0.0022    -0.0180  -0.0087   0.0033 -0.0093
# duration       -0.0009 -0.0065   0.0103    -0.0151  -0.0118  -0.0077 -0.0009
# campaign        0.0046 -0.0069  -0.0072     0.0004   0.0328  -0.0110  0.0052
# pdays          -0.0344 -0.0285  -0.0379    -0.0466   0.0801  -0.0106  0.0003
# previous        0.0244  0.0210   0.0387     0.0388  -0.1024   0.0213 -0.0013
# emp.var.rate   -0.0004 -0.0083  -0.0842    -0.0438   0.2033  -0.0602  0.0018
# cons.price.idx  0.0009 -0.0160  -0.0575    -0.0816   0.1681  -0.0805 -0.0024
# cons.conf.idx   0.1294  0.0528  -0.0338     0.0788   0.0265  -0.0338 -0.0120
# euribor3m       0.0108 -0.0079  -0.0919    -0.0364   0.1953  -0.0593  0.0001
# nr.employed    -0.0177 -0.0196  -0.0862    -0.0415   0.1898  -0.0459  0.0039
#
#                  month  day_of_week  duration  campaign   pdays  previous  \
# age            -0.0249      -0.0176   -0.0009    0.0046 -0.0344    0.0244
# job            -0.0332      -0.0008   -0.0065   -0.0069 -0.0285    0.0210
# marital        -0.0076       0.0022    0.0103   -0.0072 -0.0379    0.0387
# education      -0.0827      -0.0180   -0.0151    0.0004 -0.0466    0.0388
# default        -0.0158      -0.0087   -0.0118    0.0328  0.0801   -0.1024
# housing        -0.0181       0.0033   -0.0077   -0.0110 -0.0106    0.0213
# loan           -0.0057      -0.0093   -0.0009    0.0052  0.0003   -0.0013
# month           1.0000       0.0277    0.0037   -0.0621 -0.0479    0.1032
# day_of_week     0.0277       1.0000    0.0219   -0.0383 -0.0095   -0.0041
# duration        0.0037       0.0219    1.0000   -0.0717 -0.0476    0.0206
# campaign       -0.0621      -0.0383   -0.0717    1.0000  0.0526   -0.0791
# pdays          -0.0479      -0.0095   -0.0476    0.0526  1.0000   -0.5875
# previous        0.1032      -0.0041    0.0206   -0.0791 -0.5875    1.0000
# emp.var.rate   -0.1788       0.0332   -0.0280    0.1508  0.2710   -0.4205
# cons.price.idx -0.0042       0.0056    0.0053    0.1278  0.0789   -0.2031
# cons.conf.idx   0.0097       0.0415   -0.0082   -0.0137 -0.0913   -0.0509
# euribor3m      -0.1173       0.0390   -0.0329    0.1351  0.2969   -0.4545
# nr.employed    -0.2214       0.0284   -0.0447    0.1441  0.3726   -0.5013
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                  -0.0004          0.0009         0.1294     0.0108
# job                  -0.0083         -0.0160         0.0528    -0.0079
# marital              -0.0842         -0.0575        -0.0338    -0.0919
# education            -0.0438         -0.0816         0.0788    -0.0364
# default               0.2033          0.1681         0.0265     0.1953
# housing              -0.0602         -0.0805        -0.0338    -0.0593
# loan                  0.0018         -0.0024        -0.0120     0.0001
# month                -0.1788         -0.0042         0.0097    -0.1173
# day_of_week           0.0332          0.0056         0.0415     0.0390
# duration             -0.0280          0.0053        -0.0082    -0.0329
# campaign              0.1508          0.1278        -0.0137     0.1351
# pdays                 0.2710          0.0789        -0.0913     0.2969
# previous             -0.4205         -0.2031        -0.0509    -0.4545
# emp.var.rate          1.0000          0.7753         0.1960     0.9722
# cons.price.idx        0.7753          1.0000         0.0590     0.6882
# cons.conf.idx         0.1960          0.0590         1.0000     0.2777
# euribor3m             0.9722          0.6882         0.2777     1.0000
# nr.employed           0.9070          0.5220         0.1005     0.9452
#
#                 nr.employed
# age                 -0.0177
# job                 -0.0196
# marital             -0.0862
# education           -0.0415
# default              0.1898
# housing             -0.0459
# loan                 0.0039
# month               -0.2214
# day_of_week          0.0284
# duration            -0.0447
# campaign             0.1441
# pdays                0.3726
# previous            -0.5013
# emp.var.rate         0.9070
# cons.price.idx       0.5220
# cons.conf.idx        0.1005
# euribor3m            0.9452
# nr.employed          1.0000

# %%
# Display descriptive statistics
bank.describe()
# Out:
#              age        job    marital  education    default    housing  \
# count 41188.0000 41188.0000 41188.0000 41188.0000 41188.0000 41188.0000
# mean     40.0241     3.7246     1.1728     3.7472     0.2089     1.0717
# std      10.4212     3.5946     0.6089     2.1365     0.4067     0.9853
# min      17.0000     0.0000     0.0000     0.0000     0.0000     0.0000
# 25%      32.0000     0.0000     1.0000     2.0000     0.0000     0.0000
# 50%      38.0000     2.0000     1.0000     3.0000     0.0000     2.0000
# 75%      47.0000     7.0000     2.0000     6.0000     0.0000     2.0000
# max      98.0000    11.0000     3.0000     7.0000     2.0000     2.0000
#
#             loan    contact      month  day_of_week   duration   campaign  \
# count 41188.0000 41188.0000 41188.0000   41188.0000 41188.0000 41188.0000
# mean      0.3274     0.3653     4.2309       2.0046   258.2850     2.5676
# std       0.7236     0.4815     2.3200       1.3976   259.2792     2.7700
# min       0.0000     0.0000     0.0000       0.0000     0.0000     1.0000
# 25%       0.0000     0.0000     3.0000       1.0000   102.0000     1.0000
# 50%       0.0000     0.0000     4.0000       2.0000   180.0000     2.0000
# 75%       0.0000     1.0000     6.0000       3.0000   319.0000     3.0000
# max       2.0000     1.0000     9.0000       4.0000  4918.0000    56.0000
#
#            pdays   previous   poutcome  emp.var.rate  cons.price.idx  \
# count 41188.0000 41188.0000 41188.0000    41188.0000      41188.0000
# mean    962.4755     0.1730     0.9301        0.0819         93.5757
# std     186.9109     0.4949     0.3629        1.5710          0.5788
# min       0.0000     0.0000     0.0000       -3.4000         92.2010
# 25%     999.0000     0.0000     1.0000       -1.8000         93.0750
# 50%     999.0000     0.0000     1.0000        1.1000         93.7490
# 75%     999.0000     0.0000     1.0000        1.4000         93.9940
# max     999.0000     7.0000     2.0000        1.4000         94.7670
#
#        cons.conf.idx  euribor3m  nr.employed          y
# count     41188.0000 41188.0000   41188.0000 41188.0000
# mean        -40.5026     3.6213    5167.0359     0.1127
# std           4.6282     1.7344      72.2515     0.3162
# min         -50.8000     0.6340    4963.6000     0.0000
# 25%         -42.7000     1.3440    5099.1000     0.0000
# 50%         -41.8000     4.8570    5191.0000     0.0000
# 75%         -36.4000     4.9610    5228.1000     0.0000
# max         -26.9000     5.0450    5228.1000     1.0000

# %%
# Finding Correlation Between Target and Remaining Variables
bank.corrwith(bank['y'])
# Out:
# age               0.0304
# job               0.0251
# marital           0.0462
# education         0.0578
# default          -0.0994
# housing           0.0116
# loan             -0.0049
# contact          -0.1448
# month            -0.0061
# day_of_week       0.0160
# duration          0.4053
# campaign         -0.0664
# pdays            -0.3249
# previous          0.2302
# poutcome          0.1298
# emp.var.rate     -0.2983
# cons.price.idx   -0.1362
# cons.conf.idx     0.0549
# euribor3m        -0.3078
# nr.employed      -0.3547
# y                 1.0000
# dtype: float64

# %%
#Identify the variables to normalize with minmaxscalar
cols=['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
       'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed']

# %%
#Step -10
# identify the Independent and Target (dependent variables)
IndepVar = []
for col in bank.columns:
    if col != 'y':
        IndepVar.append(col)
TargetVar = 'y'
x = bank[IndepVar]
y = bank[TargetVar]

# %%
# Random oversampling can be implemented using the RandomOverSampler class

from imblearn.over_sampling import RandomOverSampler

oversample = RandomOverSampler(sampling_strategy=0.250)

x_over, y_over = oversample.fit_resample(x, y)

print(x_over.shape)

print(y_over.shape)
# Out:
# (45685, 20)
# (45685,)

# %%
#Step -11
# Splitting the dataset into train and test 

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_over, y_over, test_size = 0.30, random_state = 42)

# Display the shape 

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((31979, 20), (13706, 20), (31979,), (13706,))

# %%
#Step -12
# Scaling the features by using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

x_train[cols] = mmscaler.fit_transform(x_train[cols])
x_train = pd.DataFrame(x_train)

x_test[cols] = mmscaler.fit_transform(x_test[cols])
x_test = pd.DataFrame(x_test)

# %%
y_count = y_train.value_counts()
print("proportion: ",y_count[0]/y_count[1],":1")
# Out:
# proportion:  4.01395421762308 :1

# %%
#Load the result file for SVM
SVMResults=pd.read_csv(r"C:\Users\saiko\Downloads\EMResults.csv",header=0)
#Display the  first five records
SVMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %% [markdown]
# # SVM-Linear Kernel

# %%
# Training the SVM algorithm with train dataset

from sklearn.svm import SVC

ModelSVM1 = SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, 
                probability=True, tol=0.001, cache_size=200, class_weight=None, verbose=False, 
                max_iter=- 1, decision_function_shape='ovr', break_ties=False, random_state=None)

# Train the model with train data 

ModelSVM1 = ModelSVM1.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVM1.predict(x_test)
y_pred_prob = ModelSVM1.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Linear")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual,ModelSVM1.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
new_row = {'Model Name' : "SVM - Linear",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Linear
# Confusion matrix :
#  [[ 2024   735]
#  [  886 10061]]
# Outcome values :
#  2024 735 886 10061
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.73      0.71      2759
#            0       0.93      0.92      0.93     10947
#
#     accuracy                           0.88     13706
#    macro avg       0.81      0.83      0.82     13706
# weighted avg       0.88      0.88      0.88     13706
#
# Accuracy : 88.2 %
# Precision : 69.6 %
# Recall : 73.4 %
# F1 Score : 0.714
# Specificity or True Negative Rate : 91.9 %
# Balanced Accuracy : 82.6 %
# MCC : 0.64
# roc_auc_score: 0.826

# %%
#Display the results of SVM Algorithm
SVMResults
# Out:
#      Model Name True_Positive False_Negative False_Positive True_Negative  \
# 0  SVM - Linear          2024            735            886         10061
#
#    Accuracy  Precision  Recall  F1 Score  Specificity    MCC  ROC_AUC_Score  \
# 0    0.8820     0.6960  0.7340    0.7140       0.9190 0.6400         0.8263
#
#    Balanced Accuracy
# 0             0.8260

# %% [markdown]
# # Polynomial Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMPoly = SVC(kernel='poly', degree=2, probability=True)

# Train the model

ModelSVMPoly.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMPoly.predict(x_test)
y_pred_prob = ModelSVMPoly.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Polynominal")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMPoly.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
new_row = {'Model Name' : "SVM - Polynomial",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Polynominal
# Confusion matrix :
#  [[ 2015   744]
#  [  892 10055]]
# Outcome values :
#  2015 744 892 10055
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.69      0.73      0.71      2759
#            0       0.93      0.92      0.92     10947
#
#     accuracy                           0.88     13706
#    macro avg       0.81      0.82      0.82     13706
# weighted avg       0.88      0.88      0.88     13706
#
# Accuracy : 88.1 %
# Precision : 69.3 %
# Recall : 73.0 %
# F1 Score : 0.711
# Specificity or True Negative Rate : 91.9 %
# Balanced Accuracy : 82.4 %
# MCC : 0.636
# roc_auc_score: 0.824

# %%
#Display the results of SVM Algorithm
SVMResults
# Out:
#          Model Name True_Positive False_Negative False_Positive True_Negative  \
# 0      SVM - Linear          2024            735            886         10061
# 1  SVM - Polynomial          2015            744            892         10055
#
#    Accuracy  Precision  Recall  F1 Score  Specificity    MCC  ROC_AUC_Score  \
# 0    0.8820     0.6960  0.7340    0.7140       0.9190 0.6400         0.8263
# 1    0.8810     0.6930  0.7300    0.7110       0.9190 0.6360         0.8244
#
#    Balanced Accuracy
# 0             0.8260
# 1             0.8240

# %% [markdown]
# # Gaussian Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMGaussian = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMGaussian.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMGaussian.predict(x_test)
y_pred_prob = ModelSVMGaussian.predict_proba(x_test)

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Print the model name
    
print('Model Name: ', "SVM - Gaussian")

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMGaussian.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
new_row = {'Model Name' : "SVM - Gaussian",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Gaussian
# Confusion matrix :
#  [[2649  110]
#  [2245 8702]]
# Outcome values :
#  2649 110 2245 8702
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.54      0.96      0.69      2759
#            0       0.99      0.79      0.88     10947
#
#     accuracy                           0.83     13706
#    macro avg       0.76      0.88      0.79     13706
# weighted avg       0.90      0.83      0.84     13706
#
# Accuracy : 82.8 %
# Precision : 54.1 %
# Recall : 96.0 %
# F1 Score : 0.692
# Specificity or True Negative Rate : 79.5 %
# Balanced Accuracy : 87.8 %
# MCC : 0.632
# roc_auc_score: 0.878

# %% [markdown]
# # Sigmoid Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMSig = SVC(kernel='sigmoid', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMSig.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMSig.predict(x_test)
y_pred_prob = ModelSVMSig.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Sigmoid")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMSig.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
new_row = {'Model Name' : "SVM - Sigmoid",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Sigmoid
# Confusion matrix :
#  [[1415 1344]
#  [5635 5312]]
# Outcome values :
#  1415 1344 5635 5312
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.20      0.51      0.29      2759
#            0       0.80      0.49      0.60     10947
#
#     accuracy                           0.49     13706
#    macro avg       0.50      0.50      0.45     13706
# weighted avg       0.68      0.49      0.54     13706
#
# Accuracy : 49.1 %
# Precision : 20.1 %
# Recall : 51.3 %
# F1 Score : 0.289
# Specificity or True Negative Rate : 48.5 %
# Balanced Accuracy : 49.9 %
# MCC : -0.002
# roc_auc_score: 0.499

# %%
#Display the results of SVM Algorithm
SVMResults
# Out:
#          Model Name True_Positive False_Negative False_Positive True_Negative  \
# 0      SVM - Linear          2024            735            886         10061
# 1  SVM - Polynomial          2015            744            892         10055
# 2    SVM - Gaussian          2649            110           2245          8702
# 3     SVM - Sigmoid          1415           1344           5635          5312
#
#    Accuracy  Precision  Recall  F1 Score  Specificity     MCC  ROC_AUC_Score  \
# 0    0.8820     0.6960  0.7340    0.7140       0.9190  0.6400         0.8263
# 1    0.8810     0.6930  0.7300    0.7110       0.9190  0.6360         0.8244
# 2    0.8280     0.5410  0.9600    0.6920       0.7950  0.6320         0.8775
# 3    0.4910     0.2010  0.5130    0.2890       0.4850 -0.0020         0.4991
#
#    Balanced Accuracy
# 0             0.8260
# 1             0.8240
# 2             0.8780
# 3             0.4990

# %%
#Load the result file for KNN
KNNResults=pd.read_csv(r"C:\Users\saiko\OneDrive\Documents\KNN_Results.csv",header=0)
#Display the  first five records
KNNResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, KNN K Value, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %% [markdown]
# # KNN Algorithm

# %%
# Bild KNN Model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):
    
    k = a
    
    # Build the model
    
    ModelKNN = KNeighborsClassifier(n_neighbors=k)
    
    # Train the model
    
    ModelKNN.fit(x_train, y_train)
    
    # Predict the model
    
    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)
    
    print('KNN_K_value = ', a)
    
    # Print the model name
    
    print('Model Name: ', ModelKNN)
    
    # confusion matrix in sklearn
    
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report
    
    # actual values
    
    actual = y_test
    
    # predicted values
    
    predicted = y_pred
    
    # confusion matrix
    
    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)
    
    # outcome values order in sklearn
    
    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)
    
    # classification report for precision, recall f1-score and accuracy
    
    C_Report = classification_report(actual,predicted,labels=[1,0])
    
    print('Classification report : \n', C_Report)
    
    # calculating the metrics
    
    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);
    
    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model
    
    from math import sqrt
    
    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)
    
    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)
    
    # Area under ROC curve 
    
    from sklearn.metrics import roc_curve, roc_auc_score
    
    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    KNNResults = KNNResults.append(new_row, ignore_index=True)
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[ 2183   576]
#  [  905 10042]]
# Outcome values :
#  2183 576 905 10042
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.79      0.75      2759
#            0       0.95      0.92      0.93     10947
#
#     accuracy                           0.89     13706
#    macro avg       0.83      0.85      0.84     13706
# weighted avg       0.90      0.89      0.89     13706
#
# Accuracy : 89.2 %
# Precision : 70.7 %
# Recall : 79.1 %
# F1 Score : 0.747
# Specificity or True Negative Rate : 91.7 %
# Balanced Accuracy : 85.4 %
# MCC : 0.68
# roc_auc_score: 0.854
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[ 1473  1286]
#  [  539 10408]]
# Outcome values :
#  1473 1286 539 10408
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.73      0.53      0.62      2759
#            0       0.89      0.95      0.92     10947
#
#     accuracy                           0.87     13706
#    macro avg       0.81      0.74      0.77     13706
# weighted avg       0.86      0.87      0.86     13706
#
# Accuracy : 86.7 %
# Precision : 73.2 %
# Recall : 53.4 %
# F1 Score : 0.617
# Specificity or True Negative Rate : 95.1 %
# Balanced Accuracy : 74.2 %
# MCC : 0.549
# roc_auc_score: 0.742
# KNN_K_value =  3
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[1768  991]
#  [ 987 9960]]
# Outcome values :
#  1768 991 987 9960
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.64      0.64      0.64      2759
#            0       0.91      0.91      0.91     10947
#
#     accuracy                           0.86     13706
#    macro avg       0.78      0.78      0.78     13706
# weighted avg       0.86      0.86      0.86     13706
#
# Accuracy : 85.6 %
# Precision : 64.2 %
# Recall : 64.1 %
# F1 Score : 0.641
# Specificity or True Negative Rate : 91.0 %
# Balanced Accuracy : 77.6 %
# MCC : 0.551
# roc_auc_score: 0.775
# KNN_K_value =  4
# Model Name:  KNeighborsClassifier(n_neighbors=4)
# Confusion matrix :
#  [[ 1301  1458]
#  [  566 10381]]
# Outcome values :
#  1301 1458 566 10381
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.47      0.56      2759
#            0       0.88      0.95      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.79      0.71      0.74     13706
# weighted avg       0.84      0.85      0.84     13706
#
# Accuracy : 85.2 %
# Precision : 69.7 %
# Recall : 47.2 %
# F1 Score : 0.562
# Specificity or True Negative Rate : 94.8 %
# Balanced Accuracy : 71.0 %
# MCC : 0.491
# roc_auc_score: 0.71
# KNN_K_value =  5
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[ 1516  1243]
#  [  804 10143]]
# Outcome values :
#  1516 1243 804 10143
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.55      0.60      2759
#            0       0.89      0.93      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.77      0.74      0.75     13706
# weighted avg       0.84      0.85      0.85     13706
#
# Accuracy : 85.1 %
# Precision : 65.3 %
# Recall : 54.9 %
# F1 Score : 0.597
# Specificity or True Negative Rate : 92.7 %
# Balanced Accuracy : 73.8 %
# MCC : 0.509
# roc_auc_score: 0.738
# KNN_K_value =  6
# Model Name:  KNeighborsClassifier(n_neighbors=6)
# Confusion matrix :
#  [[ 1253  1506]
#  [  558 10389]]
# Outcome values :
#  1253 1506 558 10389
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.69      0.45      0.55      2759
#            0       0.87      0.95      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.78      0.70      0.73     13706
# weighted avg       0.84      0.85      0.84     13706
#
# Accuracy : 84.9 %
# Precision : 69.2 %
# Recall : 45.4 %
# F1 Score : 0.548
# Specificity or True Negative Rate : 94.9 %
# Balanced Accuracy : 70.2 %
# MCC : 0.477
# roc_auc_score: 0.702
# KNN_K_value =  7
# Model Name:  KNeighborsClassifier(n_neighbors=7)
# Confusion matrix :
#  [[ 1401  1358]
#  [  726 10221]]
# Outcome values :
#  1401 1358 726 10221
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.51      0.57      2759
#            0       0.88      0.93      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.77      0.72      0.74     13706
# weighted avg       0.84      0.85      0.84     13706
#
# Accuracy : 84.8 %
# Precision : 65.9 %
# Recall : 50.8 %
# F1 Score : 0.573
# Specificity or True Negative Rate : 93.4 %
# Balanced Accuracy : 72.1 %
# MCC : 0.489
# roc_auc_score: 0.721
# KNN_K_value =  8
# Model Name:  KNeighborsClassifier(n_neighbors=8)
# Confusion matrix :
#  [[ 1195  1564]
#  [  499 10448]]
# Outcome values :
#  1195 1564 499 10448
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.43      0.54      2759
#            0       0.87      0.95      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.79      0.69      0.72     13706
# weighted avg       0.84      0.85      0.83     13706
#
# Accuracy : 84.9 %
# Precision : 70.5 %
# Recall : 43.3 %
# F1 Score : 0.537
# Specificity or True Negative Rate : 95.4 %
# Balanced Accuracy : 69.4 %
# MCC : 0.472
# roc_auc_score: 0.694
# KNN_K_value =  9
# Model Name:  KNeighborsClassifier(n_neighbors=9)
# Confusion matrix :
#  [[ 1351  1408]
#  [  633 10314]]
# Outcome values :
#  1351 1408 633 10314
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.68      0.49      0.57      2759
#            0       0.88      0.94      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.78      0.72      0.74     13706
# weighted avg       0.84      0.85      0.84     13706
#
# Accuracy : 85.1 %
# Precision : 68.1 %
# Recall : 49.0 %
# F1 Score : 0.57
# Specificity or True Negative Rate : 94.2 %
# Balanced Accuracy : 71.6 %
# MCC : 0.492
# roc_auc_score: 0.716
# KNN_K_value =  10
# Model Name:  KNeighborsClassifier(n_neighbors=10)
# Confusion matrix :
#  [[ 1155  1604]
#  [  486 10461]]
# Outcome values :
#  1155 1604 486 10461
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.42      0.53      2759
#            0       0.87      0.96      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.79      0.69      0.72     13706
# weighted avg       0.83      0.85      0.83     13706
#
# Accuracy : 84.8 %
# Precision : 70.4 %
# Recall : 41.9 %
# F1 Score : 0.525
# Specificity or True Negative Rate : 95.6 %
# Balanced Accuracy : 68.8 %
# MCC : 0.462
# roc_auc_score: 0.687
# KNN_K_value =  11
# Model Name:  KNeighborsClassifier(n_neighbors=11)
# Confusion matrix :
#  [[ 1256  1503]
#  [  608 10339]]
# Outcome values :
#  1256 1503 608 10339
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.67      0.46      0.54      2759
#            0       0.87      0.94      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.77      0.70      0.73     13706
# weighted avg       0.83      0.85      0.83     13706
#
# Accuracy : 84.6 %
# Precision : 67.4 %
# Recall : 45.5 %
# F1 Score : 0.543
# Specificity or True Negative Rate : 94.4 %
# Balanced Accuracy : 70.0 %
# MCC : 0.468
# roc_auc_score: 0.7
# KNN_K_value =  12
# Model Name:  KNeighborsClassifier(n_neighbors=12)
# Confusion matrix :
#  [[ 1114  1645]
#  [  496 10451]]
# Outcome values :
#  1114 1645 496 10451
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.69      0.40      0.51      2759
#            0       0.86      0.95      0.91     10947
#
#     accuracy                           0.84     13706
#    macro avg       0.78      0.68      0.71     13706
# weighted avg       0.83      0.84      0.83     13706
#
# Accuracy : 84.4 %
# Precision : 69.2 %
# Recall : 40.4 %
# F1 Score : 0.51
# Specificity or True Negative Rate : 95.5 %
# Balanced Accuracy : 68.0 %
# MCC : 0.446
# roc_auc_score: 0.679
# KNN_K_value =  13
# Model Name:  KNeighborsClassifier(n_neighbors=13)
# Confusion matrix :
#  [[ 1203  1556]
#  [  582 10365]]
# Outcome values :
#  1203 1556 582 10365
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.67      0.44      0.53      2759
#            0       0.87      0.95      0.91     10947
#
#     accuracy                           0.84     13706
#    macro avg       0.77      0.69      0.72     13706
# weighted avg       0.83      0.84      0.83     13706
#
# Accuracy : 84.4 %
# Precision : 67.4 %
# Recall : 43.6 %
# F1 Score : 0.529
# Specificity or True Negative Rate : 94.7 %
# Balanced Accuracy : 69.2 %
# MCC : 0.456
# roc_auc_score: 0.691
# KNN_K_value =  14
# Model Name:  KNeighborsClassifier(n_neighbors=14)
# Confusion matrix :
#  [[ 1100  1659]
#  [  472 10475]]
# Outcome values :
#  1100 1659 472 10475
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.40      0.51      2759
#            0       0.86      0.96      0.91     10947
#
#     accuracy                           0.84     13706
#    macro avg       0.78      0.68      0.71     13706
# weighted avg       0.83      0.84      0.83     13706
#
# Accuracy : 84.5 %
# Precision : 70.0 %
# Recall : 39.9 %
# F1 Score : 0.508
# Specificity or True Negative Rate : 95.7 %
# Balanced Accuracy : 67.8 %
# MCC : 0.447
# roc_auc_score: 0.678
# KNN_K_value =  15
# Model Name:  KNeighborsClassifier(n_neighbors=15)
# Confusion matrix :
#  [[ 1174  1585]
#  [  536 10411]]
# Outcome values :
#  1174 1585 536 10411
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.69      0.43      0.53      2759
#            0       0.87      0.95      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.78      0.69      0.72     13706
# weighted avg       0.83      0.85      0.83     13706
#
# Accuracy : 84.5 %
# Precision : 68.7 %
# Recall : 42.6 %
# F1 Score : 0.525
# Specificity or True Negative Rate : 95.1 %
# Balanced Accuracy : 68.8 %
# MCC : 0.457
# roc_auc_score: 0.688
# KNN_K_value =  16
# Model Name:  KNeighborsClassifier(n_neighbors=16)
# Confusion matrix :
#  [[ 1084  1675]
#  [  465 10482]]
# Outcome values :
#  1084 1675 465 10482
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.39      0.50      2759
#            0       0.86      0.96      0.91     10947
#
#     accuracy                           0.84     13706
#    macro avg       0.78      0.68      0.71     13706
# weighted avg       0.83      0.84      0.83     13706
#
# Accuracy : 84.4 %
# Precision : 70.0 %
# Recall : 39.3 %
# F1 Score : 0.503
# Specificity or True Negative Rate : 95.8 %
# Balanced Accuracy : 67.6 %
# MCC : 0.444
# roc_auc_score: 0.675
# KNN_K_value =  17
# Model Name:  KNeighborsClassifier(n_neighbors=17)
# Confusion matrix :
#  [[ 1159  1600]
#  [  535 10412]]
# Outcome values :
#  1159 1600 535 10412
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.68      0.42      0.52      2759
#            0       0.87      0.95      0.91     10947
#
#     accuracy                           0.84     13706
#    macro avg       0.78      0.69      0.71     13706
# weighted avg       0.83      0.84      0.83     13706
#
# Accuracy : 84.4 %
# Precision : 68.4 %
# Recall : 42.0 %
# F1 Score : 0.521
# Specificity or True Negative Rate : 95.1 %
# Balanced Accuracy : 68.6 %
# MCC : 0.452
# roc_auc_score: 0.686
# KNN_K_value =  18
# Model Name:  KNeighborsClassifier(n_neighbors=18)
# Confusion matrix :
#  [[ 1097  1662]
#  [  457 10490]]
# Outcome values :
#  1097 1662 457 10490
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.40      0.51      2759
#            0       0.86      0.96      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.78      0.68      0.71     13706
# weighted avg       0.83      0.85      0.83     13706
#
# Accuracy : 84.5 %
# Precision : 70.6 %
# Recall : 39.8 %
# F1 Score : 0.509
# Specificity or True Negative Rate : 95.8 %
# Balanced Accuracy : 67.8 %
# MCC : 0.45
# roc_auc_score: 0.678
# KNN_K_value =  19
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[ 1151  1608]
#  [  518 10429]]
# Outcome values :
#  1151 1608 518 10429
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.69      0.42      0.52      2759
#            0       0.87      0.95      0.91     10947
#
#     accuracy                           0.84     13706
#    macro avg       0.78      0.68      0.71     13706
# weighted avg       0.83      0.84      0.83     13706
#
# Accuracy : 84.5 %
# Precision : 69.0 %
# Recall : 41.7 %
# F1 Score : 0.52
# Specificity or True Negative Rate : 95.3 %
# Balanced Accuracy : 68.5 %
# MCC : 0.453
# roc_auc_score: 0.685
# KNN_K_value =  20
# Model Name:  KNeighborsClassifier(n_neighbors=20)
# Confusion matrix :
#  [[ 1080  1679]
#  [  468 10479]]
# Outcome values :
#  1080 1679 468 10479
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.39      0.50      2759
#            0       0.86      0.96      0.91     10947
#
#     accuracy                           0.84     13706
#    macro avg       0.78      0.67      0.70     13706
# weighted avg       0.83      0.84      0.83     13706
#
# Accuracy : 84.3 %
# Precision : 69.8 %
# Recall : 39.1 %
# F1 Score : 0.502
# Specificity or True Negative Rate : 95.7 %
# Balanced Accuracy : 67.4 %
# MCC : 0.442
# roc_auc_score: 0.674

# %%
#Display the results of KNN Algorithm
KNNResults
# Out:
#                               Model Name KNN K Value True_Positive  \
# 0    KNeighborsClassifier(n_neighbors=1)           1          2183
# 1    KNeighborsClassifier(n_neighbors=2)           2          1473
# 2    KNeighborsClassifier(n_neighbors=3)           3          1768
# 3    KNeighborsClassifier(n_neighbors=4)           4          1301
# 4                 KNeighborsClassifier()           5          1516
# 5    KNeighborsClassifier(n_neighbors=6)           6          1253
# 6    KNeighborsClassifier(n_neighbors=7)           7          1401
# 7    KNeighborsClassifier(n_neighbors=8)           8          1195
# 8    KNeighborsClassifier(n_neighbors=9)           9          1351
# 9   KNeighborsClassifier(n_neighbors=10)          10          1155
# 10  KNeighborsClassifier(n_neighbors=11)          11          1256
# 11  KNeighborsClassifier(n_neighbors=12)          12          1114
# 12  KNeighborsClassifier(n_neighbors=13)          13          1203
# 13  KNeighborsClassifier(n_neighbors=14)          14          1100
# 14  KNeighborsClassifier(n_neighbors=15)          15          1174
# 15  KNeighborsClassifier(n_neighbors=16)          16          1084
# 16  KNeighborsClassifier(n_neighbors=17)          17          1159
# 17  KNeighborsClassifier(n_neighbors=18)          18          1097
# 18  KNeighborsClassifier(n_neighbors=19)          19          1151
# 19  KNeighborsClassifier(n_neighbors=20)          20          1080
#
#    False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0             576            905         10042    0.8920     0.7070  0.7910
# 1            1286            539         10408    0.8670     0.7320  0.5340
# 2             991            987          9960    0.8560     0.6420  0.6410
# 3            1458            566         10381    0.8520     0.6970  0.4720
# 4            1243            804         10143    0.8510     0.6530  0.5490
# 5            1506            558         10389    0.8490     0.6920  0.4540
# 6            1358            726         10221    0.8480     0.6590  0.5080
# 7            1564            499         10448    0.8490     0.7050  0.4330
# 8            1408            633         10314    0.8510     0.6810  0.4900
# 9            1604            486         10461    0.8480     0.7040  0.4190
# 10           1503            608         10339    0.8460     0.6740  0.4550
# 11           1645            496         10451    0.8440     0.6920  0.4040
# 12           1556            582         10365    0.8440     0.6740  0.4360
# 13           1659            472         10475    0.8450     0.7000  0.3990
# 14           1585            536         10411    0.8450     0.6870  0.4260
# 15           1675            465         10482    0.8440     0.7000  0.3930
# 16           1600            535         10412    0.8440     0.6840  0.4200
# 17           1662            457         10490    0.8450     0.7060  0.3980
# 18           1608            518         10429    0.8450     0.6900  0.4170
# 19           1679            468         10479    0.8430     0.6980  0.3910
#
#     F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0     0.7470       0.9170 0.6800         0.8543             0.8540
# 1     0.6170       0.9510 0.5490         0.7423             0.7420
# 2     0.6410       0.9100 0.5510         0.7753             0.7760
# 3     0.5620       0.9480 0.4910         0.7099             0.7100
# 4     0.5970       0.9270 0.5090         0.7380             0.7380
# 5     0.5480       0.9490 0.4770         0.7016             0.7020
# 6     0.5730       0.9340 0.4890         0.7207             0.7210
# 7     0.5370       0.9540 0.4720         0.6938             0.6940
# 8     0.5700       0.9420 0.4920         0.7159             0.7160
# 9     0.5250       0.9560 0.4620         0.6871             0.6880
# 10    0.5430       0.9440 0.4680         0.6998             0.7000
# 11    0.5100       0.9550 0.4460         0.6792             0.6800
# 12    0.5290       0.9470 0.4560         0.6914             0.6920
# 13    0.5080       0.9570 0.4470         0.6778             0.6780
# 14    0.5250       0.9510 0.4570         0.6883             0.6880
# 15    0.5030       0.9580 0.4440         0.6752             0.6760
# 16    0.5210       0.9510 0.4520         0.6856             0.6860
# 17    0.5090       0.9580 0.4500         0.6779             0.6780
# 18    0.5200       0.9530 0.4530         0.6849             0.6850
# 19    0.5020       0.9570 0.4420         0.6743             0.6740

# %% [markdown]
# # Compare the classification Algorithms

# %%
# Load the results file for classification
EMResults = pd.read_csv(r"C:\Users\saiko\OneDrive\Documents\EMResults.csv",header=0)
EMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Create objects of classification algorithms with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=1)
ModelGNB = GaussianNB()
ModelSVM = SVC(kernel='linear', random_state = 42, class_weight='balanced', probability=True)

# Evalution matrix for all the algorithms

MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelGNB, ModelSVM]
#MM = [ModelLR, ModelDC, ModelRF, ModelET]
for models in MM:
            
    # Train the model training dataset
    
    models.fit(x_train, y_train)
    
    # Prediction the model with test dataset
    
    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve 

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    Model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    #
    plt.plot(fpr, tpr, label= 'Classification Model' % Model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive': tp,
               'False_Negative': fn, 
               'False_Positive': fp, 
               'True_Negative': tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults = EMResults.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
#======================================================================================================================>
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[ 1951   808]
#  [  815 10132]]
# Outcome values :
#  1951 808 815 10132
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.71      0.71      2759
#            0       0.93      0.93      0.93     10947
#
#     accuracy                           0.88     13706
#    macro avg       0.82      0.82      0.82     13706
# weighted avg       0.88      0.88      0.88     13706
#
# Accuracy : 88.2 %
# Precision : 70.5 %
# Recall : 70.7 %
# F1 Score : 0.706
# Specificity or True Negative Rate : 92.6 %
# Balanced Accuracy : 81.6 %
# MCC : 0.632
# roc_auc_score: 0.816
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[1861  898]
#  [1118 9829]]
# Outcome values :
#  1861 898 1118 9829
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.62      0.67      0.65      2759
#            0       0.92      0.90      0.91     10947
#
#     accuracy                           0.85     13706
#    macro avg       0.77      0.79      0.78     13706
# weighted avg       0.86      0.85      0.85     13706
#
# Accuracy : 85.3 %
# Precision : 62.5 %
# Recall : 67.5 %
# F1 Score : 0.649
# Specificity or True Negative Rate : 89.8 %
# Balanced Accuracy : 78.6 %
# MCC : 0.556
# roc_auc_score: 0.786
# -----------------------------------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[2418  341]
#  [ 959 9988]]
# Outcome values :
#  2418 341 959 9988
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.72      0.88      0.79      2759
#            0       0.97      0.91      0.94     10947
#
#     accuracy                           0.91     13706
#    macro avg       0.84      0.89      0.86     13706
# weighted avg       0.92      0.91      0.91     13706
#
# Accuracy : 90.5 %
# Precision : 71.6 %
# Recall : 87.6 %
# F1 Score : 0.788
# Specificity or True Negative Rate : 91.2 %
# Balanced Accuracy : 89.4 %
# MCC : 0.734
# roc_auc_score: 0.894
# -----------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[ 2324   435]
#  [  573 10374]]
# Outcome values :
#  2324 435 573 10374
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.80      0.84      0.82      2759
#            0       0.96      0.95      0.95     10947
#
#     accuracy                           0.93     13706
#    macro avg       0.88      0.89      0.89     13706
# weighted avg       0.93      0.93      0.93     13706
#
# Accuracy : 92.6 %
# Precision : 80.2 %
# Recall : 84.2 %
# F1 Score : 0.822
# Specificity or True Negative Rate : 94.8 %
# Balanced Accuracy : 89.5 %
# MCC : 0.776
# roc_auc_score: 0.895
# -----------------------------------------------------------------------------------------------------
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[ 2183   576]
#  [  905 10042]]
# Outcome values :
#  2183 576 905 10042
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.79      0.75      2759
#            0       0.95      0.92      0.93     10947
#
#     accuracy                           0.89     13706
#    macro avg       0.83      0.85      0.84     13706
# weighted avg       0.90      0.89      0.89     13706
#
# Accuracy : 89.2 %
# Precision : 70.7 %
# Recall : 79.1 %
# F1 Score : 0.747
# Specificity or True Negative Rate : 91.7 %
# Balanced Accuracy : 85.4 %
# MCC : 0.68
# roc_auc_score: 0.854
# -----------------------------------------------------------------------------------------------------
# Model Name:  GaussianNB()
# Confusion matrix :
#  [[2053  706]
#  [1692 9255]]
# Outcome values :
#  2053 706 1692 9255
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.55      0.74      0.63      2759
#            0       0.93      0.85      0.89     10947
#
#     accuracy                           0.83     13706
#    macro avg       0.74      0.79      0.76     13706
# weighted avg       0.85      0.83      0.83     13706
#
# Accuracy : 82.5 %
# Precision : 54.8 %
# Recall : 74.4 %
# F1 Score : 0.631
# Specificity or True Negative Rate : 84.5 %
# Balanced Accuracy : 79.4 %
# MCC : 0.53
# roc_auc_score: 0.795
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(class_weight='balanced', kernel='linear', probability=True, random_state=42)
# Confusion matrix :
#  [[2619  140]
#  [2415 8532]]
# Outcome values :
#  2619 140 2415 8532
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.52      0.95      0.67      2759
#            0       0.98      0.78      0.87     10947
#
#     accuracy                           0.81     13706
#    macro avg       0.75      0.86      0.77     13706
# weighted avg       0.89      0.81      0.83     13706
#
# Accuracy : 81.4 %
# Precision : 52.0 %
# Recall : 94.9 %
# F1 Score : 0.672
# Specificity or True Negative Rate : 77.9 %
# Balanced Accuracy : 86.4 %
# MCC : 0.606
# roc_auc_score: 0.864
# -----------------------------------------------------------------------------------------------------

# %%
#Display the comparison results
EMResults.head(10)
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()          1951
# 1                           DecisionTreeClassifier()          1861
# 2  (DecisionTreeClassifier(max_features='sqrt', r...          2418
# 3  (ExtraTreeClassifier(random_state=1361249456),...          2324
# 4                KNeighborsClassifier(n_neighbors=1)          2183
# 5                                       GaussianNB()          2053
# 6  SVC(class_weight='balanced', kernel='linear', ...          2619
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0            808            815         10132    0.8820     0.7050  0.7070
# 1            898           1118          9829    0.8530     0.6250  0.6750
# 2            341            959          9988    0.9050     0.7160  0.8760
# 3            435            573         10374    0.9260     0.8020  0.8420
# 4            576            905         10042    0.8920     0.7070  0.7910
# 5            706           1692          9255    0.8250     0.5480  0.7440
# 6            140           2415          8532    0.8140     0.5200  0.9490
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0    0.7060       0.9260 0.6320         0.8163             0.8160
# 1    0.6490       0.8980 0.5560         0.7862             0.7860
# 2    0.7880       0.9120 0.7340         0.8944             0.8940
# 3    0.8220       0.9480 0.7760         0.8950             0.8950
# 4    0.7470       0.9170 0.6800         0.8543             0.8540
# 5    0.6310       0.8450 0.5300         0.7948             0.7940
# 6    0.6720       0.7790 0.6060         0.8643             0.8640

# %%
# Assuming you have also predicted using ExtraTreesClassifier(Model ET)
# Since having more accuracy we have choosen it for prediction
y_pred=ModelET.predict(x_test)

# %%
# Display the Final results by merging duplicate file

Results=pd.DataFrame({'y_A':y_test,'y_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal=bank_copy.merge(Results,left_index=True,right_index=True)

#Display 10 records randomly

ResultsFinal.sample(10)
# Out:
#        age          job   marital            education  default housing loan  \
# 36663   32       admin.    single    university.degree       no      no   no
# 19058   40   technician   married  professional.course       no     yes   no
# 13867   34     services  divorced             basic.9y       no      no   no
# 28338   40       admin.  divorced    university.degree       no      no   no
# 18986   54   technician   married    university.degree       no     yes   no
# 11635   55       admin.  divorced    university.degree       no     yes   no
# 6025    29  blue-collar    single             basic.9y       no     yes   no
# 1464    57     services  divorced          high.school  unknown      no  yes
# 89      34       admin.   married          high.school       no     yes   no
# 8270    47   technician    single  professional.course  unknown      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 36663   cellular   jun         fri       462         1    999         0
# 19058   cellular   aug         tue       115         1    999         0
# 13867   cellular   jul         fri       684         1    999         0
# 28338   cellular   apr         wed       143         2    999         0
# 18986  telephone   aug         mon       652         2    999         0
# 11635  telephone   jun         fri        17         6    999         0
# 6025   telephone   may         tue       330         2    999         0
# 1464   telephone   may         thu       185         2    999         0
# 89     telephone   may         mon       188         2    999         0
# 8270   telephone   jun         tue       126         1    999         0
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 36663  nonexistent       -2.9000         92.9630       -40.8000     1.2680
# 19058  nonexistent        1.4000         93.4440       -36.1000     4.9680
# 13867  nonexistent        1.4000         93.9180       -42.7000     4.9630
# 28338  nonexistent       -1.8000         93.0750       -47.1000     1.4450
# 18986  nonexistent        1.4000         93.4440       -36.1000     4.9700
# 11635  nonexistent        1.4000         94.4650       -41.8000     4.9590
# 6025   nonexistent        1.1000         93.9940       -36.4000     4.8570
# 1464   nonexistent        1.1000         93.9940       -36.4000     4.8550
# 89     nonexistent        1.1000         93.9940       -36.4000     4.8570
# 8270   nonexistent        1.4000         94.4650       -41.8000     4.8640
#
#        nr.employed    y  y_A  y_P
# 36663    5076.2000  yes    1    1
# 19058    5228.1000   no    0    0
# 13867    5228.1000   no    0    1
# 28338    5099.1000  yes    1    0
# 18986    5228.1000  yes    1    0
# 11635    5228.1000   no    0    0
# 6025     5191.0000   no    0    0
# 1464     5191.0000   no    0    0
# 89       5191.0000   no    0    0
# 8270     5228.1000   no    0    0

# %%
# Display the Final results by data frame 

Results = pd.DataFrame({ 'y_A':y_test, 'y_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = pd.DataFrame({'y_A': y_test, 'y_P': y_pred})

#Display 10 records randomly 
ResultsFinal.sample(10)
# Out:
#        y_A  y_P
# 25853    1    1
# 20137    0    0
# 33978    0    0
# 144      0    0
# 40644    1    1
# 24025    1    1
# 11264    0    0
# 24718    0    0
# 23349    0    0
# 43301    1    1

# %%
EMResults.head(10)
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()          1951
# 1                           DecisionTreeClassifier()          1861
# 2  (DecisionTreeClassifier(max_features='sqrt', r...          2418
# 3  (ExtraTreeClassifier(random_state=1361249456),...          2324
# 4                KNeighborsClassifier(n_neighbors=1)          2183
# 5                                       GaussianNB()          2053
# 6  SVC(class_weight='balanced', kernel='linear', ...          2619
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0            808            815         10132    0.8820     0.7050  0.7070
# 1            898           1118          9829    0.8530     0.6250  0.6750
# 2            341            959          9988    0.9050     0.7160  0.8760
# 3            435            573         10374    0.9260     0.8020  0.8420
# 4            576            905         10042    0.8920     0.7070  0.7910
# 5            706           1692          9255    0.8250     0.5480  0.7440
# 6            140           2415          8532    0.8140     0.5200  0.9490
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0    0.7060       0.9260 0.6320         0.8163             0.8160
# 1    0.6490       0.8980 0.5560         0.7862             0.7860
# 2    0.7880       0.9120 0.7340         0.8944             0.8940
# 3    0.8220       0.9480 0.7760         0.8950             0.8950
# 4    0.7470       0.9170 0.6800         0.8543             0.8540
# 5    0.6310       0.8450 0.5300         0.7948             0.7940
# 6    0.6720       0.7790 0.6060         0.8643             0.8640
